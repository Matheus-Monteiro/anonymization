# %% [markdown]
# # Final Result

# %% [markdown]
# ### Set initial settings

# %%
import sys
import warnings

# Add base directory in path
sys.path.append('../../')

# Ignore future warning
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ### Import libs

# %%
from src.file import find_csv_files
from src.plot import plot_by_model

# %%
csv_files = find_csv_files(root_folder="../")
csv_files
# Out:
# ['../original_data/original_data_result.csv',
#  '../mutual_information/mutual_information_3_result.csv',
#  '../low_variance/low_variance_result.csv',
#  '../lasso/lasso_result.csv',
#  '../extra_tree/extra_tree_6_result.csv',
#  '../qui_square/qui_square_3_result.csv',
#  '../anova/anova_4_result.csv']

# %% [markdown]
# ## KNN

# %%
plot_by_model(csv_files=csv_files, title="KNN - Accuracy", model_name="KNN", metric_name="accuracy", plot_path="./knn_accuracy.png", y_lim_bottom=50)

# %%
plot_by_model(csv_files=csv_files, title="KNN - F1 Score", model_name="KNN", metric_name="f1_score", plot_path="./knn_f1_score.png")

# %% [markdown]
# ## DecisionTree

# %%
plot_by_model(csv_files=csv_files, title="DecisionTree - Accuracy", model_name="DecisionTree", metric_name="accuracy", plot_path="./decision_tree_accuracy.png", y_lim_bottom=50)

# %%
plot_by_model(csv_files=csv_files, title="DecisionTree - F1 Score", model_name="DecisionTree", metric_name="f1_score", plot_path="./decision_tree_f1_score.png")

# %% [markdown]
# ## RandomForest

# %%
plot_by_model(csv_files=csv_files, title="RandomForest - Accuracy", model_name="RandomForest", metric_name="accuracy", plot_path="./random_forest_accuracy.png", y_lim_bottom=50)

# %%
plot_by_model(csv_files=csv_files, title="RandomForest - F1 Score", model_name="RandomForest", metric_name="f1_score", plot_path="./random_forest_f1_score.png")

# %% [markdown]
# ## GaussianNB

# %%
plot_by_model(csv_files=csv_files, title="GaussianNB - Accuracy", model_name="GaussianNB", metric_name="accuracy", plot_path="./gaussian_nb_accuracy.png", y_lim_bottom=50)

# %%
plot_by_model(csv_files=csv_files, title="GaussianNB - F1 Score", model_name="GaussianNB", metric_name="f1_score", plot_path="./gaussian_nb_f1_score.png")
